# %% [markdown]
# ## Instalando bibliotecas

# %%
# !pip install pandas plotly ipykernel odfpy -q

# %% [markdown]
# ## Importando base de dados usando pandas

# %%
import pandas as pd

tabela = pd.read_csv('gestao_equipamentos.csv')

# %% [markdown]
# ## Extraindo os dados necessários para a análise

# %%
tabela = tabela.drop(columns=['TOMBO', 'ATRIBUIDO', 'REQUERENTE', 'TECNICO_DEVOLUCAO', 'ID_CHAMADO', 'STATUS', 'SETOR'])

# %% [markdown]
# ## Visualizando o dataframe

# %%
display(tabela)
# Out:
# /usr/local/lib/python3.10/dist-packages/google/colab/_dataframe_summarizer.py:88: UserWarning: Parsing dates in %d/%m/%Y format when dayfirst=False (the default) was specified. Pass `dayfirst=True` or specify a format to silence this warning.
#   cast_date_col = pd.to_datetime(column, errors="coerce")
#                        MODELO      MOTIVO_ENTRADA DATA_ENTRADA DATA_DEVOLUCAO
# 0            HP COMPAQ DC5800            NÃO LIGA   19/01/2023            NaN
# 1            HP COMPAQ DC5800           DEVOLUÇÃO   20/01/2023            NaN
# 2                DATEN DCA1-S            NÃO LIGA   13/02/2023            NaN
# 3                         NaN            NÃO LIGA   13/02/2023            NaN
# 4    INFOWAY SM-3330 VERMELHA      TROCA DE FONTE   23/02/2023            NaN
# ..                        ...                 ...          ...            ...
# 896             POSITIVO D360  SISTEMA CORROMPIDO   16/05/2024            NaN
# 897  INFOWAY SM-3330 VERMELHA     TROCA DE COOLER   16/05/2024            NaN
# 898      INFOWAY SM-3322 AZUL            NÃO LIGA   16/05/2024            NaN
# 899      INFOWAY SM-3322 AZUL     TROCA DE COOLER   20/05/2024            NaN
# 900             POSITIVO D360  ATUALIZAÇÃO DE S.O   20/04/2024            NaN
#
# [901 rows x 4 columns]

# %%
print(tabela['DATA_ENTRADA'].dtype)
print(tabela['DATA_DEVOLUCAO'].dtype)
# Out:
# object
# object

# %% [markdown]
# ## Visualizando os modelos de equipamentos e o número de vezes que esse equipamento já transitou pelo setor de T.I

# %%
display(tabela['MODELO'].value_counts())
# Out:
# MODELO
# POSITIVO D360               172
# INFOWAY SM-3330 VERMELHA    155
# POSITIVO D540               127
# INFOWAY SM-3322 AZUL        119
# POSITIVO C610               102
# POSITIVO DMF                 36
# LENOVO M90                   34
# HP COMPAQ DC5800             28
# POSITIVO C6300               26
# DATEN DCA1-S                 23
# POSITIVO D820                19
# LENOVO M70Q                  11
# HP 402 G1                    10
# LENOVO M920S                  7
# NTBK-VAIO-VJF157F11X          6
# HP COMPAQ PRO 6000            4
# LENOVO M75S-2                 4
# NTBK-LENOVOTHINKPAD           3
# Name: count, dtype: int64

# %% [markdown]
# ## Analisando os modelos de equipamentos, assim como seu motivo de entrada mais recorrente

# %%
import plotly.express as px

grafico_entrada = px.histogram(tabela, x='MODELO', color='MOTIVO_ENTRADA')

grafico_entrada.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.24.1.min.js"></script>                <div id="0afbb22c-da0d-44b3-b0bb-bdb57ba1d804" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("0afbb22c-da0d-44b3-b0bb-bdb57ba1d804")) {                    Plotly.newPlot(                        "0afbb22c-da0d-44b3-b0bb-bdb57ba1d804",                        [{"alignmentgroup":"True","bingroup":"x","hovertemplate":"MOTIVO_ENTRADA=N\u00c3O LIGA\u003cbr\u003eMODELO=%{x}\u003cbr\u003ecount=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"N\u00c3O LIGA","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"N\u00c3O LIGA","offsetgroup":"N\u00c3O LIGA","orientation":"v","showlegend":true,"x":["HP COMPAQ DC5800","DATEN DCA1-S",null,"DATEN DCA1-S",null,null,"INFOWAY SM-3322 AZUL","LENOVO M920S","POSITIVO DMF","INFOWAY SM-3330 VERMELHA","INFOWAY SM-3330 VERMELHA","INFOWAY SM-3322 AZUL","POSITIVO C6300","INFOWAY SM-3330 VERMELHA","POSITIVO D540","INFOWAY SM-3330 VERMELHA","POSITIVO C6300","LENOVO M90","POSITIVO D540","INFOWAY SM-3322 AZUL","POSITIVO C610","POSITIVO D540","INFOWAY SM-3330 VERMELHA","INFOWAY SM-3330 VERMELHA","INFOWAY SM-3322 AZUL","INFOWAY SM-3330 VERMELHA","POSITIVO D360","INFOWAY SM-3322 AZUL","INFOWAY SM-3330 VERMELHA","POSITIVO C6300","POSITIVO D540","INFOWAY SM-3330 VERMELHA","INFOWAY SM-3330 VERMELHA","POSITIVO D360","POSITIVO D540","POSITIVO D360","POSITIVO C610","POSITIVO D360","POSITIVO D540","POSITIVO C6300","INFOWAY SM-3322 AZUL","INFOWAY SM-3330 VERMELHA","POSITIVO D540","POSITIVO D540","HP COMPAQ DC5800","POSITIVO D360","INFOWAY SM-3322 AZUL","LENOVO M90","INFOWAY SM-3330 VERMELHA","POSITIVO D360","INFOWAY SM-3330 VERMELHA","INFOWAY SM-3330 VERMELHA","INFOWAY SM-3330 VERMELHA","HP 402 G1","INFOWAY SM-3322 AZUL","INFOWAY SM-3330 VERMELHA","INFOWAY SM-3330 VERMELHA","POSITIVO D360","INFOWAY SM-3330 VERMELHA","INFOWAY SM-3330 VERMELHA","POSITIVO D820","POSITIVO D360","INFOWAY SM-3322 AZUL","INFOWAY SM-3322 AZUL","POSITIVO D360","INFOWAY SM-3330 VERMELHA",null,"POSITIVO D540","POSITIVO C610","DATEN DCA1-S","POSITIVO D360","POSITIVO D360","POSITIVO D360","INFOWAY SM-3322 AZUL","POSITIVO D360","INFOWAY SM-3330 VERMELHA","POSITIVO D540","POSITIVO DMF","POSITIVO D360","POSITIVO D360","POSITIVO DMF","POSITIVO D360","POSITIVO D540","POSITIVO D540","POSITIVO D540","POSITIVO D540","POSITIVO DMF","POSITIVO D540","INFOWAY SM-3322 AZUL","POSITIVO D820","POSITIVO D540","POSITIVO D540","POSITIVO D820","INFOWAY SM-3322 AZUL"],"xaxis":"x","yaxis":"y","type":"histogram"},{"alignmentgroup":"True","bingroup":"x","hovertemplate":"MOTIVO_ENTRADA=DEVOLU\u00c7\u00c3O\u003cbr\u003eMODELO=%{x}\u003cbr\u003ecount=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"DEVOLU\u00c7\u00c3O","marker":{"color":"#EF553B","pattern":{"shape":""}},"name":"DEVOLU\u00c7\u00c3O","offsetgroup":"DEVOLU\u00c7\u00c3O","orientation":"v","showlegend":true,"x":["HP COMPAQ DC5800","INFOWAY SM-3330 VERMELHA","INFOWAY SM-3322 AZUL","INFOWAY SM-3330 VERMELHA","INFOWAY SM-3322 AZUL","POSITIVO D360","DATEN DCA1-S","POSITIVO D540","INFOWAY SM-3322 AZUL","INFOWAY SM-3330 VERMELHA","POSITIVO D540","POSITIVO DMF","INFOWAY SM-3322 AZUL","INFOWAY SM-3330 VERMELHA","POSITIVO D360","INFOWAY SM-3330 VERMELHA","INFOWAY SM-3330 VERMELHA","POSITIVO D360","POSITIVO D820","INFOWAY SM-3330 VERMELHA","POSITIVO D360","INFOWAY SM-3330 VERMELHA","HP COMPAQ PRO 6000","INFOWAY SM-3330 VERMELHA","POSITIVO D820","INFOWAY SM-3330 VERMELHA",null,"INFOWAY SM-3330 VERMELHA","LENOVO M920S","POSITIVO D540","HP COMPAQ DC5800","POSITIVO D360","POSITIVO D360","INFOWAY SM-3330 VERMELHA","POSITIVO D540","POSITIVO DMF","HP COMPAQ DC5800","HP COMPAQ DC5800","HP COMPAQ DC5800","POSITIVO DMF","POSITIVO DMF","INFOWAY SM-3330 VERMELHA","HP COMPAQ DC5800","POSITIVO D360","INFOWAY ...

# %% [markdown]
# ## Calculando o tempo médio para a realização de cada procedimento ou resolução de defeito

# %%
# Os dados faltantes dentro da coluna DATA_DEVOLUCAO foram descartados para fim de análise mais precisa.

tabela = tabela.dropna()

# %%
display(tabela)
# Out:
#                        MODELO         MOTIVO_ENTRADA DATA_ENTRADA  \
# 15       INFOWAY SM-3322 AZUL               NÃO LIGA   06/03/2023
# 16   INFOWAY SM-3330 VERMELHA     SISTEMA CORROMPIDO   07/03/2023
# 17   INFOWAY SM-3330 VERMELHA  LENTIDÃO E TRAVAMENTO   07/03/2023
# 18              POSITIVO D360             FORMATAÇÃO   08/03/2023
# 19               LENOVO M920S               NÃO LIGA   09/03/2023
# ..                        ...                    ...          ...
# 888             POSITIVO D540               NÃO LIGA   13/05/2024
# 889             POSITIVO D360     ATUALIZAÇÃO DE S.O   13/05/2024
# 890             POSITIVO C610             FORMATAÇÃO   13/05/2024
# 892              DATEN DCA1-S             FORMATAÇÃO   14/05/2024
# 893             POSITIVO D360             FORMATAÇÃO   14/05/2024
#
#     DATA_DEVOLUCAO
# 15      23/03/2023
# 16      10/03/2023
# 17      15/03/2023
# 18      10/03/2023
# 19      14/03/2023
# ..             ...
# 888     14/05/2024
# 889     14/05/2024
# 890     16/05/2024
# 892     16/05/2024
# 893     15/05/2024
#
# [505 rows x 4 columns]

# %% [markdown]
# ## Convertendo os valores das colunas DATA_ENTRADA e DATA_DEVOLUCAO para o formato datetime

# %%
tabela['DATA_ENTRADA'] = pd.to_datetime(tabela['DATA_ENTRADA'], format = '%d/%m/%Y', dayfirst=True)
tabela['DATA_DEVOLUCAO'] = pd.to_datetime(tabela['DATA_DEVOLUCAO'], format = '%d/%m/%Y', dayfirst=True)

# %%
print(tabela['DATA_ENTRADA'].dtype)
print(tabela['DATA_DEVOLUCAO'].dtype)
# Out:
# datetime64[ns]
# datetime64[ns]

# %% [markdown]
# ## Considerando somente DATA_ENTRADA menores que DATA_DEVOLUCAO

# %%
tabela = tabela[tabela['DATA_ENTRADA'] <= tabela['DATA_DEVOLUCAO']]

# %%
display(tabela)
# Out:
#                        MODELO         MOTIVO_ENTRADA DATA_ENTRADA  \
# 15       INFOWAY SM-3322 AZUL               NÃO LIGA   2023-03-06
# 16   INFOWAY SM-3330 VERMELHA     SISTEMA CORROMPIDO   2023-03-07
# 17   INFOWAY SM-3330 VERMELHA  LENTIDÃO E TRAVAMENTO   2023-03-07
# 18              POSITIVO D360             FORMATAÇÃO   2023-03-08
# 19               LENOVO M920S               NÃO LIGA   2023-03-09
# ..                        ...                    ...          ...
# 888             POSITIVO D540               NÃO LIGA   2024-05-13
# 889             POSITIVO D360     ATUALIZAÇÃO DE S.O   2024-05-13
# 890             POSITIVO C610             FORMATAÇÃO   2024-05-13
# 892              DATEN DCA1-S             FORMATAÇÃO   2024-05-14
# 893             POSITIVO D360             FORMATAÇÃO   2024-05-14
#
#     DATA_DEVOLUCAO
# 15      2023-03-23
# 16      2023-03-10
# 17      2023-03-15
# 18      2023-03-10
# 19      2023-03-14
# ..             ...
# 888     2024-05-14
# 889     2024-05-14
# 890     2024-05-16
# 892     2024-05-16
# 893     2024-05-15
#
# [492 rows x 4 columns]

# %% [markdown]
# ## Fazendo o cálculo do tempo de manutenção baseado na DATA_ENTRADA e DATA_DEVOLUCAO

# %%
tabela['TEMPO_MANUTENCAO'] = tabela['DATA_DEVOLUCAO'] - tabela['DATA_ENTRADA']

# %%
print(tabela['TEMPO_MANUTENCAO'].dtype)
# Out:
# timedelta64[ns]

# %% [markdown]
# ## Convertendo o tempo para dias

# %%
tabela['TEMPO_MANUTENCAO_SEGUNDOS'] = tabela['TEMPO_MANUTENCAO'].dt.total_seconds()

# %%
tabela['TEMPO_MANUTENCAO_DIAS'] = tabela['TEMPO_MANUTENCAO_SEGUNDOS'] / 86400

# %%
motivos_agrupados = tabela.groupby('MOTIVO_ENTRADA')

# %%
media_dias = motivos_agrupados['TEMPO_MANUTENCAO_DIAS'].mean()

# %%
media_dias = media_dias.round(2)

# %%
import plotly.graph_objects as go

grafico_tempo_medio = go.Figure(data=[go.Bar(x=media_dias.index, y=media_dias.values)])

grafico_tempo_medio.update_layout(
    title='TEMPO MÉDIO DE MANUTENÇÃO POR MOTIVO DE ENTRADA',
    xaxis_title='MOTIVO DE ENTRADA',
    yaxis_title='TEMPO MÉDIO EM MANUTENÇÃO (DIAS)'
)

grafico_tempo_medio.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.24.1.min.js"></script>                <div id="8e4abfe8-76c8-4172-bb7b-4291abe9528a" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("8e4abfe8-76c8-4172-bb7b-4291abe9528a")) {                    Plotly.newPlot(                        "8e4abfe8-76c8-4172-bb7b-4291abe9528a",                        [{"x":["ATUALIZA\u00c7\u00c3O DE S.O","DEVOLU\u00c7\u00c3O","FORMATA\u00c7\u00c3O","LENTID\u00c3O E TRAVAMENTO","LIMPEZA","N\u00c3O LIGA","PLACA-M\u00c3E COM DEFEITO","SISTEMA CORROMPIDO","TROCA DE BATERIA DA BIOS","TROCA DE COOLER","TROCA DE FONTE","TROCA DE HD","TROCA DE PLACA DE REDE"],"y":[6.6,9.7,4.0,6.8,5.6,5.6,3.0,6.6,3.8,8.5,6.3,8.1,1.9],"type":"bar"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmapgl":[{"type":"heatmapgl","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"contourcarpet":[{"type":"contourcarpet","colorbar":{"outlinewidth":0,"ticks":""}}],"contour":[{"type":"contour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"surface":[{"type":"surface","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"mesh3d":[{"type":"mesh3d","colorbar":{"outlinewidth":0,"ticks":""}}],"scatter":[{"fillpattern":{"fillmode":"overlay","size":10,"solidity":0.2},"type":"scatter"}],"parcoords":[{"type":"parcoords","line":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"scatterpolargl":[{"type":"scatterpolargl","marker":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"bar":[{"error_x":{"color":"#2a3f5f"},"error_y":{"color":"#2a3f5f"},"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"}],"scattergeo":[{"type":"scattergeo","marker":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"scatt ...
